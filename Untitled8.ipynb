# %% [markdown]
# <a href="https://colab.research.google.com/github/mayankraj25/CasualPortfolio/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
from warnings import filterwarnings
filterwarnings('ignore')
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "countries of the world.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "fernandol/countries-of-the-world",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
import pandas as pd
df.isnull().sum()
df = df.replace(',', '', regex=True)
df = df.apply(pd.to_numeric, errors='coerce')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Country']=le.fit_transform(df['Country'])
df['Region']=le.fit_transform(df['Region'])

# %%
df.head()
# Out:
#    Country  Region  Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0        0       0    31056997          647500                         480
# 1        1       3     3581655           28748                        1246
# 2        2       6    32930091         2381740                         138
# 3        3       8       57794             199                        2904
# 4        4      10       71201             468                        1521
#
#    Coastline (coast/area ratio)  Net migration  \
# 0                             0         2306.0
# 1                           126         -493.0
# 2                             4          -39.0
# 3                          5829        -2071.0
# 4                             0           66.0
#
#    Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 0                             16307.0               700.0         360.0
# 1                              2152.0              4500.0         865.0
# ...

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='mean')
df=imputer.fit_transform(df)

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df=scaler.fit_transform(df)
